# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/train.csv')

# %%
df.head()
# Out:
#    selling_price  new-price  km_driven  owner_type  mileage  engine  \
# 0          39.00     74.410       49.0           1    16.55    2993
# 1           5.40     14.950      104.5           1    22.32    1582
# 2           5.89     14.275       38.2           1    17.40    1497
# 3           4.50     10.670       90.0           1    18.60    1197
# 4           2.90      8.950       85.0           1    16.47    1198
#
#    max_power  seats       brand  model    variant  transmission_type_Manual  \
# 0     258.00      5         bmw     x3  xdrive30d                         0
# 1     126.30      5     hyundai  verna        1.6                         1
# 2     117.30      5       honda   city          i                         1
# 3      81.83      5     hyundai    i20     sportz                         1
# 4      74.00      5  volkswagen   polo        1.2                         1
#
#    fuel_type_Diesel  fuel_type_Electric  fuel_type_Petrol  \
# ...
